# %%
#Loading Manhattan EZ pass data set

import pandas as pd
#import polyline

manhattanEZPass = pd.read_csv("sample_data/NYC OpenData EZ Pass Reader.csv")


print(manhattanEZPass.info(),'\n')
print(manhattanEZPass.shape)
manhattanEZPass.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   sid                           351 non-null    int64
#  1   link_name                     351 non-null    object
#  2   borough                       351 non-null    object
#  3   polyline                      351 non-null    object
#  4   link_length_ft                351 non-null    float64
#  5   aggregation_period_sec        351 non-null    int64
#  6   n_samples                     351 non-null    int64
#  7   median_calculation_timestamp  351 non-null    object
#  8   median_tt_sec                 351 non-null    float64
#  9   median_speed_fps              351 non-null    float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 27.6+ KB
# None
#
# (351, 10)
#     sid                                          link_name    borough  \
# ...

# %%
#Loading NYC Real-Time Traffic Speed Data

nycTrafficData = pd.read_csv("sample_data/NYC Real-Time Traffic Speed Data.csv")

nycTrafficData.head()
# Out:
#     sid                                          link_name    borough  \
# 0  2012  49th Street - Westbound - Lexington Ave to Mad...  Manhattan
# 1  3002  Lexington Avenue - Southbound - 57th St to 49t...  Manhattan
# 2  5006       3rd Avenue - Northbound - 49th St to 57th St  Manhattan
# 3  6003  57th Street - Westbound - 3rd Ave to Lexington...  Manhattan
# 4  8118   34th Street - Westbound - Madison Ave to 5th Ave  Manhattan
#
#                polyline  link_length_ft  aggregation_period_sec  n_samples  \
# 0    ecwwFdynbMgC~HgC~H         1013.97                     900         14
# 1  ybxwF`bnbM??vRxMzJfG         2109.11                     900         20
# 2        a_wwFfonbMq^aV         2105.67                     900         20
# 3        a_xwFxwmbMeC|H          502.77                     900         39
# 4        {puwFdxpbMeC|H          502.84                     900         28
#
#   median_calculation_timestamp  median_tt_sec  median_speed_fps
# ...
